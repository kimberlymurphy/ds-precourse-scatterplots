# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

cars_data = pd.read_csv('../data/cars.csv', sep='|')
cars_data.rename(columns={'Unnamed: 0': 'make_model'}, inplace=True)
cars_data.head()
# Out:
#           make_model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
print((cars_data))
# Out:
#              make_model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
for i in range(1960, 1981):
    print(i)
# Out:
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980

# %%
data = []

for i in range(1960,1981):
    data[i] = ""

data[1960]=[0.71 ,0.63 ,0.85 ,0.44]
data[1961].append([0.61 ,0.69 ,0.92 ,0.55])
data[1962].append([0.72 ,0.77 ,0.92 ,0.60])
data[1963].append([0.83 ,0.80 ,1.00 ,0.77])
data[1964].append([0.92 ,1.00 ,1.24 ,1.00])
data[1965].append([1.16 ,1.30 ,1.45 ,1.25])
data[1966].append([1.26 ,1.38 ,1.86 ,1.56])
data[1967].append([1.53 ,1.59 ,1.83 ,1.86])
data[1968].append([1.53 ,2.07 ,2.34 ,2.25])
data[1969].append([2.16 ,2.43 ,2.70 ,2.25])
data[1970].append([2.79 ,3.42 ,3.69 ,3.60])
data[1971].append([3.60 ,4.32 ,4.32 ,4.05])
data[1972].append([4.86 ,5.04 ,5.04 ,4.41])
data[1973].append([5.58 ,5.85 ,6.57 ,5.31])
data[1974].append([6.03 ,6.39 ,6.93 ,5.85])
data[1975].append([6.93 ,7.74 ,7.83 ,6.12])
data[1976].append([7.74 ,8.91 ,8.28 ,6.84])
data[1977].append([9.54 ,10.26 ,9.54 ,8.73])
data[1978].append([11.88 ,12.06 ,12.15 ,8.91])
data[1979].append([14.04 ,12.96 ,14.85 ,9.99])
data[1980].append([16.20 ,14.67 ,16.02 ,11.61])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-ff36d3f51f31> in <module>
#       2
#       3 for i in range(1960,1981):
# ----> 4     data[i] = ""
#       5
#       6 data[1960]=[0.71 ,0.63 ,0.85 ,0.44]
#
# IndexError: list assignment index out of range

# %%
#Try it as a list
data = []
data.append([0.71 ,0.63 ,0.85 ,0.44])
data.append([0.61 ,0.69 ,0.92 ,0.55])
data.append([0.72 ,0.77 ,0.92 ,0.60])
data.append([0.83 ,0.80 ,1.00 ,0.77])
data.append([0.92 ,1.00 ,1.24 ,1.00])
data.append([1.16 ,1.30 ,1.45 ,1.25])
data.append([1.26 ,1.38 ,1.86 ,1.56])
data.append([1.53 ,1.59 ,1.83 ,1.86])
data.append([1.53 ,2.07 ,2.34 ,2.25])
data.append([2.16 ,2.43 ,2.70 ,2.25])
data.append([2.79 ,3.42 ,3.69 ,3.60])
data.append([3.60 ,4.32 ,4.32 ,4.05])
data.append([4.86 ,5.04 ,5.04 ,4.41])
data.append([5.58 ,5.85 ,6.57 ,5.31])
data.append([6.03 ,6.39 ,6.93 ,5.85])
data.append([6.93 ,7.74 ,7.83 ,6.12])
data.append([7.74 ,8.91 ,8.28 ,6.84])
data.append([9.54 ,10.26 ,9.54 ,8.73])
data.append([11.88 ,12.06 ,12.15 ,8.91])
data.append([14.04 ,12.96 ,14.85 ,9.99])
data.append([16.20 ,14.67 ,16.02 ,11.61])

#Ok... dict
pData = {}
for i in range(1960, 1981):
    for j in range(0,4):
        pData[i+0.25*j] = data[i-1960][j]

#Ugh, unpack (? should have started this way)
myBad = pData.items()
myBad = sorted(myBad) 
x, y = zip(*myBad) 
print(type(myBad))
plt.plot(x,y)
plt.show()
# Out:
# <class 'list'>
